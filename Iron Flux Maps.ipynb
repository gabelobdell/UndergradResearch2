# %%
import openfile as of
import dataprocess as dps
import plotmaps as pm
import numpy as np

# %%
#Iron Flux Data
Ironflux1850_2014 = of.opennc("/Volumes/BackupDrive/Research/Undergrad Research/Spring 25/Files/Iron Flux Data/Oceanic Iron Flux", "b.e21.BHISTcmip6.f09_g17.LE2-1001.001.pop.h.IRON_FLUX.185001-201412.nc")
# Out:
# /Volumes/BackupDrive/Undergrad-Research-GabeL-main/Code/openfile.py:7: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   fileout = xr.open_dataset(file)

# %%
IronFlux1850_1874 = dps.getslice(Ironflux1850_2014, "time", '1850-02-01','1875-01-01')
IronFlux1990_2014 = dps.getslice(Ironflux1850_2014, "time", '1990-02-01','2015-01-01')

# %%
pm.plotTSZone(Ironflux1850_2014, "IRON_FLUX", 7, 25, 360-50, 360-20, False, 164, "Average Daily Precipitation (1850-2014)", "Precipitation (mm/day)",  1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pm.plotTSZone(Ironflux1850_2014, "IRON_FLUX", 7, 25, 360-50, 360-20, False, 164, "Average Daily Precipitation (1850-2014)", "Precipitation (mm/day)",  1)
#
# File /Volumes/BackupDrive/Undergrad-Research-GabeL-main/Code/plotmaps.py:177, in plotTSZone(dataset, variable, lat_min, lat_max, lon_min, lon_max, structured, years, title, label, scalefactor)
#     174     time = xr.decode_cf(dataset).time  # This converts CFTime to datetime64 if needed
#     176 # Select data in the region and apply scale factor
# --> 177 data = dataset[variable].sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max)) * scalefactor
#     179 # Compute mean over both latitude and longitude
#     180 regional_mean = data.mean(dim=["lat", "lon"])
#
# ...

# %%
#pm.unstrucMap("/Volumes/BackupDrive/Research/Undergrad Research/Spring 25/Files/Iron Flux Data/Oceanic Iron Flux/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.pop.h.IRON_FLUX.185001-201412.nc", IronFlux1850_1874, "Oceanic Iron Flux (1850-1874)", "Iron Flux")
# Out:
# /Volumes/BackupDrive/Undergrad-Research-GabeL-main/Code/plotmaps.py:115: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   ds = xr.open_dataset(file)
